# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha-7989/Python_Essential_Training/blob/main/05_02_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

# %% [markdown]
# ## While loops

# %% [markdown]
# **Note**: This notebook has been modified from what is shown in the video. In order to prevent bugs when the current time ends in 58 or 59 seconds, the following line:
#
# <code>wait_until = datetime.now().second + 2</code>
#
# has been changed to
#
# <code>wait_until = (datetime.now().second + 2) % 60</code>
#
# where it appears in the code samples

# %%
datetime.now().second
# Out:
# 38

# %%
wait_until = (datetime.now().second + 2) % 60

while datetime.now().second != wait_until:
    print('Still waiting!')

print(f'We are at {wait_until} seconds!')
# Out:
# Streaming output truncated to the last 5000 lines.
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# ...
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# We are at 41 seconds!

# %%
wait_until = datetime.now().second + 2

while datetime.now().second != wait_until:
    1 + 1

print(f'We are at {wait_until} seconds!')
# Out:
# We are at 46 seconds!

# %% [markdown]
# ### Pass

# %%
wait_until = (datetime.now().second + 2) % 60

while datetime.now().second != wait_until:
    pass

print(f'We are at {wait_until} seconds!')
# Out:
# We are at 10 seconds!

# %% [markdown]
# ### Break

# %%
wait_until = (datetime.now().second + 2) % 60

while True:
    if datetime.now().second == wait_until:
        print(f'We are at {wait_until} seconds!')
        break
# Out:
# We are at 22 seconds!

# %%
wait_until = (datetime.now().second + 2) % 60

while True:
    while datetime.now().second == wait_until:
        print(f'We are at {wait_until} seconds!')
        b
# Out:
# Streaming output truncated to the last 5000 lines.
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# ...
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# We are at 27 seconds!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-228203d10f55> in <cell line: 0>()
#       2
#       3 while True:
# ----> 4     while datetime.now().second == wait_until:
#       5         print(f'We are at {wait_until} seconds!')
#       6         break
#
# KeyboardInterrupt:

# %% [markdown]
# ### Continue

# %%
wait_until = (datetime.now().second + 2) % 60

while datetime.now().second != wait_until:
    continue
    print('Still waiting!')


print(f'We are at {wait_until} seconds!')
# Out:
# We are at 58 seconds!

# %%
wait_until = (datetime.now().second + 2) % 60

while True:
    if datetime.now().second < wait_until:
        continue
    break


print(f'We are at {wait_until} seconds!')
# Out:
# We are at 10 seconds!
